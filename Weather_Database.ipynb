# %%
# Import the dependencies
import random
import numpy as np
import pandas as pd
from citipy import citipy
import requests

from config import weather_api_key
from datetime import datetime

# %%
# Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low = -90.000, high = 90.000, size = 2000)
lngs = np.random.uniform(low = -180.000, high = 180.000, size = 2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Get the nearest city using the citipy module.
# Add the latitudes and longtitudes to a list
coordinates = list(lat_lngs)

# Create a list to hold the cities
cities = []

# Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 743

# %%
# Get the nearest city using the citipy module.
# Starting URL for Weather API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]
    
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})
        
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 15 | klaksvik
# Processing Record 2 of Set 15 | shahreza
# Processing Record 3 of Set 15 | rikitea
# Processing Record 4 of Set 15 | carnarvon
# Processing Record 5 of Set 15 | kruisfontein
# Processing Record 6 of Set 15 | jamestown
# Processing Record 7 of Set 15 | bengkulu
# Processing Record 8 of Set 15 | alta floresta
# Processing Record 9 of Set 15 | barrow
# Processing Record 10 of Set 15 | butaritari
# Processing Record 11 of Set 15 | lebu
# Processing Record 12 of Set 15 | hobart
# Processing Record 13 of Set 15 | piney green
# Processing Record 14 of Set 15 | kaitangata
# Processing Record 15 of Set 15 | avarua
# Processing Record 16 of Set 15 | punta arenas
# Processing Record 17 of Set 15 | port elizabeth
# Processing Record 18 of Set 15 | hunza
# City not found. Skipping...
# Processing Record 19 of Set 15 | sistranda
# Processing Record 20 of Set 15 | kirakira
# Processing Record 21 of Set 15 | hilo
# Processing Record 22 of Set 15 | mataura
# Processing Record 23 of Set 15 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 15 | richards bay
# Processing Record 25 of Set 15 | vaini
# Processing Record 26 of Set 15 | faanui
# Processing Record 27 of Set 15 | ancud
# Processing Record 28 of Set 15 | nanortalik
# Processing Record 29 of Set 15 | busselton
# Processing Record 30 of Set 15 | aden
# Processing Record 31 of Set 15 | albany
# Processing Record 32 of Set 15 | ribeira grande
# Processing Record 33 of Set 15 | port blair
# Processing Record 34 of Set 15 | grand centre
# City not found. Skipping...
# Processing Record 35 of Set 15 | yarovoye
# Processing Record 36 of Set 15 | ushuaia
# Processing Record 37 of Set 15 | camacha
# Processing Record 38 of Set 15 | qaanaaq
# Processing Record 39 of Set 15 | clyde river
# Processing Record 40 of Set 15 | tiksi
# Processing Record 41 of Set 15 | banda aceh
# Processing Record 42 of Set 15 | walvis bay
# Processing Record 43 of Set 15 | puerto leguizamo
# Processing Record 44 of Set 15 | provideniya
# Processing Record 45 of Set 15 | ponta do sol
# Processing Record 46 of Set 15 | bluff
# Processing Record 47 of Set 15 | kenai
# Processing Record 48 of Set 15 | chokurdakh
# Processing Record 49 of Set 15 | hobyo
# Processing Record 50 of Set 15 | khatanga
# Processing Record 1 of Set 16 | bredasdorp
# Processing Record 2 of Set 16 | namatanai
# Processing Record 3 of Set 16 | bodden town
# Processing Record 4 of Set 16 | hasaki
# Processing Record 5 of Set 16 | airai
# Processing Record 6 of Set 16 | cayon
# Processing Record 7 of Set 16 | alofi
# Processing Record 8 of Set 16 | hermanus
# Processing Record 9 of Set 16 | inuvik
# Processing Record 10 of Set 16 | atuona
# Processing Record 11 of Set 16 | kuche
# City not found. Skipping...
# Processing Record 12 of Set 16 | saint simons
# Processing Record 13 of Set 16 | natal
# Processing Record 14 of Set 16 | almeirim
# Processing Record 15 of Set 16 | severo-kurilsk
# Processing Record 16 of Set 16 | cazones
# Processing Record 17 of Set 16 | georgetown
# Processing Record 18 of Set 16 | faya
# Processing Record 19 of Set 16 | palana
# Processing Record 20 of Set 16 | broome
# Processing Record 21 of Set 16 | sola
# Processing Record 22 of Set 16 | chato
# Processing Record 23 of Set 16 | pangnirtung
# Processing Record 24 of Set 16 | san patricio
# Processing Record 25 of Set 16 | beruwala
# Processing Record 26 of Set 16 | vardo
# Processing Record 27 of Set 16 | san rafael
# Processing Record 28 of Set 16 | lorengau
# Processing Record 29 of Set 16 | bur gabo
# City not found. Skipping...
# Processing Record 30 of Set 16 | isangel
# Processing Record 31 of Set 16 | cabo san lucas
# Processing Record 32 of Set 16 | mosetse
# Processing Record 33 of Set 16 | luderitz
# Processing Record 34 of Set 16 | saint-philippe
# Processing Record 35 of Set 16 | xanlar
# Processing Record 36 of Set 16 | bealanana
# Processing Record 37 of Set 16 | ubinskoye
# Processing Record 38 of Set 16 | victoria
# Processing Record 39 of Set 16 | iturama
# Processing Record 40 of Set 16 | kavaratti
# Processing Record 41 of Set 16 | cape town
# Processing Record 42 of Set 16 | surt
# Processing Record 43 of Set 16 | pasewalk
# Processing Record 44 of Set 16 | khonuu
# City not found. Skipping...
# Processing Record 45 of Set 16 | attawapiskat
# City not found. Skipping...
# Processing Record 46 of Set 16 | saskylakh
# Processing Record 47 of Set 16 | kavieng
# Processing Record 48 of Set 16 | khandbari
# Processing Record 49 of Set 16 | hervey bay
# Processing Record 50 of Set 16 | kimbe
# Processing Record 1 of Set 17 | sosnovo-ozerskoye
# Processing Record 2 of Set 17 | kapaa
# Processing Record 3 of Set 17 | san lawrenz
# Processing Record 4 of Set 17 | norman wells
# Processing Record 5 of Set 17 | malakal
# Processing Record 6 of Set 17 | husavik
# Processing Record 7 of Set 17 | vila velha
# Processing Record 8 of Set 17 | chuy
# Processing Record 9 of Set 17 | constitucion
# Processing Record 10 of Set 17 | inza
# Processing Record 11 of Set 17 | pevek
# Processing Record 12 of Set 17 | puerto suarez
# Processing Record 13 of Set 17 | grindavik
# Processing Record 14 of Set 17 | mys shmidta
# City not found. Skipping...
# Processing Record 15 of Set 17 | zhaozhou
# Processing Record 16 of Set 17 | kawalu
# Processing Record 17 of Set 17 | touros
# Processing Record 18 of Set 17 | chapais
# Processing Record 19 of Set 17 | narsaq
# Processing Record 20 of Set 17 | tuktoyaktuk
# Processing Record 21 of Set 17 | nichinan
# Processing Record 22 of Set 17 | krasnoarmeysk
# Processing Record 23 of Set 17 | mar del plata
# Processing Record 24 of Set 17 | gazanjyk
# Processing Record 25 of Set 17 | castro
# Processing Record 26 of Set 17 | cap-aux-meules
# Processing Record 27 of Set 17 | chagda
# City not found. Skipping...
# Processing Record 28 of Set 17 | east london
# Processing Record 29 of Set 17 | tasiilaq
# Processing Record 30 of Set 17 | yellowknife
# Processing Record 31 of Set 17 | puksoozero
# Processing Record 32 of Set 17 | buqayq
# City not found. Skipping...
# Processing Record 33 of Set 17 | grand river south east
# City not found. Skipping...
# Processing Record 34 of Set 17 | tumannyy
# City not found. Skipping...
# Processing Record 35 of Set 17 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 36 of Set 17 | valdemarpils
# Processing Record 37 of Set 17 | hirara
# Processing Record 38 of Set 17 | vila franca do campo
# Processing Record 39 of Set 17 | sao filipe
# Processing Record 40 of Set 17 | palu
# Processing Record 41 of Set 17 | pemba
# Processing Record 42 of Set 17 | tavrichanka
# Processing Record 43 of Set 17 | bambous virieux
# Processing Record 44 of Set 17 | dikson
# Processing Record 45 of Set 17 | kargasok
# Processing Record 46 of Set 17 | deputatskiy
# Processing Record 47 of Set 17 | westport
# Processing Record 48 of Set 17 | iqaluit
# Processing Record 49 of Set 17 | tucuman
# Processing Record 50 of Set 17 | cidreira
# Processing Record 1 of Set 18 | acapulco
# Processing Record 2 of Set 18 | lindi
# Processing Record 3 of Set 18 | issoire
# Processing Record 4 of Set 18 | tsihombe
# City not found. Skipping...
# Processing Record 5 of Set 18 | yuzha
# Processing Record 6 of Set 18 | sahrak
# City not found. Skipping...
# Processing Record 7 of Set 18 | aitape
# Processing Record 8 of Set 18 | ossora
# Processing Record 9 of Set 18 | chone
# Processing Record 10 of Set 18 | mizque
# Processing Record 11 of Set 18 | sentyabrskiy
# City not found. Skipping...
# Processing Record 12 of Set 18 | pochutla
# Processing Record 13 of Set 18 | sikasso
# Processing Record 14 of Set 18 | batagay
# Processing Record 15 of Set 18 | geraldton
# Processing Record 16 of Set 18 | nikolskoye
# Processing Record 17 of Set 18 | myanaung
# Processing Record 18 of Set 18 | tamale
# Processing Record 19 of Set 18 | kyzyl-suu
# Processing Record 20 of Set 18 | vuktyl
# Processing Record 21 of Set 18 | saint-pierre
# Processing Record 22 of Set 18 | te anau
# Processing Record 23 of Set 18 | marsa matruh
# Processing Record 24 of Set 18 | uray
# Processing Record 25 of Set 18 | careiro da varzea
# Processing Record 26 of Set 18 | manacapuru
# Processing Record 27 of Set 18 | parker
# Processing Record 28 of Set 18 | esperance
# Processing Record 29 of Set 18 | berlevag
# Processing Record 30 of Set 18 | tura
# Processing Record 31 of Set 18 | savannah bight
# Processing Record 32 of Set 18 | taltal
# Processing Record 33 of Set 18 | kodiak
# Processing Record 34 of Set 18 | amderma
# City not found. Skipping...
# Processing Record 35 of Set 18 | taoudenni
# Processing Record 36 of Set 18 | inirida
# Processing Record 37 of Set 18 | avera
# Processing Record 38 of Set 18 | ugoofaaru
# Processing Record 39 of Set 18 | fairbanks
# Processing Record 40 of Set 18 | new norfolk
# Processing Record 41 of Set 18 | saldanha
# Processing Record 42 of Set 18 | labytnangi
# Processing Record 43 of Set 18 | ende
# Processing Record 44 of Set 18 | nanakuli
# Processing Record 45 of Set 18 | cherskiy
# Processing Record 46 of Set 18 | upernavik
# Processing Record 47 of Set 18 | masuda
# Processing Record 48 of Set 18 | bethel
# Processing Record 49 of Set 18 | arraial do cabo
# Processing Record 50 of Set 18 | bargal
# City not found. Skipping...
# Processing Record 1 of Set 19 | san quintin
# Processing Record 2 of Set 19 | guerrero negro
# Processing Record 3 of Set 19 | vao
# Processing Record 4 of Set 19 | manica
# Processing Record 5 of Set 19 | oga
# Processing Record 6 of Set 19 | hithadhoo
# Processing Record 7 of Set 19 | puerto ayora
# Processing Record 8 of Set 19 | sobolevo
# Processing Record 9 of Set 19 | nome
# Processing Record 10 of Set 19 | brae
# Processing Record 11 of Set 19 | catamarca
# Processing Record 12 of Set 19 | gamba
# Processing Record 13 of Set 19 | samalaeulu
# City not found. Skipping...
# Processing Record 14 of Set 19 | kupino
# Processing Record 15 of Set 19 | ibra
# Processing Record 16 of Set 19 | marawi
# Processing Record 17 of Set 19 | port keats
# Processing Record 18 of Set 19 | rulenge
# Processing Record 19 of Set 19 | lavrentiya
# Processing Record 20 of Set 19 | mersin
# Processing Record 21 of Set 19 | samur
# Processing Record 22 of Set 19 | lakes entrance
# Processing Record 23 of Set 19 | romanovka
# Processing Record 24 of Set 19 | belushya guba
# City not found. Skipping...
# Processing Record 25 of Set 19 | nhulunbuy
# Processing Record 26 of Set 19 | mahibadhoo
# Processing Record 27 of Set 19 | cooma
# Processing Record 28 of Set 19 | bandarbeyla
# Processing Record 29 of Set 19 | marzuq
# Processing Record 30 of Set 19 | kadykchan
# City not found. Skipping...
# Processing Record 31 of Set 19 | novoseleznevo
# Processing Record 32 of Set 19 | bafata
# Processing Record 33 of Set 19 | almaznyy
# Processing Record 34 of Set 19 | christchurch
# Processing Record 35 of Set 19 | vostok
# Processing Record 36 of Set 19 | arrifes
# Processing Record 37 of Set 19 | tapes
# Processing Record 38 of Set 19 | saint-joseph
# Processing Record 39 of Set 19 | horsham
# Processing Record 40 of Set 19 | pacific grove
# Processing Record 41 of Set 19 | kanker
# Processing Record 42 of Set 19 | taree
# Processing Record 43 of Set 19 | pedernales
# Processing Record 44 of Set 19 | thessalon
# Processing Record 45 of Set 19 | poum
# Processing Record 46 of Set 19 | rocha
# Processing Record 47 of Set 19 | krasnokamensk
# Processing Record 48 of Set 19 | hami
# Processing Record 49 of Set 19 | zhuhai
# Processing Record 50 of Set 19 | ilulissat
# Processing Record 1 of Set 20 | kloulklubed
# Processing Record 2 of Set 20 | umm ruwabah
# City not found. Skipping...
# Processing Record 3 of Set 20 | oriximina
# Processing Record 4 of Set 20 | gari
# Processing Record 5 of Set 20 | channel-port aux basques
# Processing Record 6 of Set 20 | portobelo
# Processing Record 7 of Set 20 | oranjemund
# Processing Record 8 of Set 20 | lasa
# Processing Record 9 of Set 20 | amga
# Processing Record 10 of Set 20 | alyangula
# Processing Record 11 of Set 20 | pasighat
# Processing Record 12 of Set 20 | pouembout
# Processing Record 13 of Set 20 | beloha
# Processing Record 14 of Set 20 | saint pete beach
# Processing Record 15 of Set 20 | florianopolis
# Processing Record 16 of Set 20 | fort nelson
# Processing Record 17 of Set 20 | kumla
# Processing Record 18 of Set 20 | brainerd
# Processing Record 19 of Set 20 | havre-saint-pierre
# Processing Record 20 of Set 20 | praia da vitoria
# Processing Record 21 of Set 20 | namtsy
# Processing Record 22 of Set 20 | pavlivka
# Processing Record 23 of Set 20 | port alfred
# Processing Record 24 of Set 20 | kahului
# Processing Record 25 of Set 20 | mahebourg
# Processing Record 26 of Set 20 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 27 of Set 20 | asau
# Processing Record 28 of Set 20 | katsuura
# Processing Record 29 of Set 20 | maues
# Processing Record 30 of Set 20 | fortuna
# Processing Record 31 of Set 20 | kandalaksha
# Processing Record 32 of Set 20 | azimur
# City not found. Skipping...
# Processing Record 33 of Set 20 | roald
# Processing Record 34 of Set 20 | sao joao da barra
# Processing Record 35 of Set 20 | tessalit
# Processing Record 36 of Set 20 | mackenzie
# Processing Record 37 of Set 20 | saint-augustin
# Processing Record 38 of Set 20 | gizo
# Processing Record 39 of Set 20 | thompson
# Processing Record 40 of Set 20 | estacion coahuila
# Processing Record 41 of Set 20 | marfino
# Processing Record 42 of Set 20 | vilcun
# Processing Record 43 of Set 20 | adrar
# Processing Record 44 of Set 20 | polistena
# Processing Record 45 of Set 20 | ketchikan
# Processing Record 46 of Set 20 | qaqortoq
# Processing Record 47 of Set 20 | ixtapa
# Processing Record 48 of Set 20 | tuatapere
# Processing Record 49 of Set 20 | vila do maio
# Processing Record 50 of Set 20 | zambezi
# Processing Record 1 of Set 21 | port augusta
# Processing Record 2 of Set 21 | komsomolskiy
# Processing Record 3 of Set 21 | svetlogorsk
# Processing Record 4 of Set 21 | abu samrah
# Processing Record 5 of Set 21 | qui nhon
# Processing Record 6 of Set 21 | namibe
# Processing Record 7 of Set 21 | khor
# Processing Record 8 of Set 21 | bubaque
# Processing Record 9 of Set 21 | samusu
# City not found. Skipping...
# Processing Record 10 of Set 21 | rudnogorsk
# Processing Record 11 of Set 21 | marcona
# City not found. Skipping...
# Processing Record 12 of Set 21 | takoradi
# Processing Record 13 of Set 21 | bud
# Processing Record 14 of Set 21 | mount gambier
# Processing Record 15 of Set 21 | san isidro
# Processing Record 16 of Set 21 | port hawkesbury
# Processing Record 17 of Set 21 | sirawai
# Processing Record 18 of Set 21 | pahrump
# Processing Record 19 of Set 21 | kangaatsiaq
# Processing Record 20 of Set 21 | prince rupert
# Processing Record 21 of Set 21 | kununurra
# Processing Record 22 of Set 21 | dolores
# Processing Record 23 of Set 21 | mayo
# Processing Record 24 of Set 21 | karkaralinsk
# City not found. Skipping...
# Processing Record 25 of Set 21 | along
# Processing Record 26 of Set 21 | nemuro
# Processing Record 27 of Set 21 | kirkland lake
# Processing Record 28 of Set 21 | filingue
# Processing Record 29 of Set 21 | tabou
# Processing Record 30 of Set 21 | saint george
# Processing Record 31 of Set 21 | novoagansk
# Processing Record 32 of Set 21 | aklavik
# Processing Record 33 of Set 21 | teacapan
# Processing Record 34 of Set 21 | coquimbo
# Processing Record 35 of Set 21 | nigran
# Processing Record 36 of Set 21 | longyearbyen
# Processing Record 37 of Set 21 | baruun-urt
# Processing Record 38 of Set 21 | pitimbu
# Processing Record 39 of Set 21 | el fuerte
# Processing Record 40 of Set 21 | kapit
# Processing Record 41 of Set 21 | palmer
# Processing Record 42 of Set 21 | tsogni
# Processing Record 43 of Set 21 | bikapur
# Processing Record 44 of Set 21 | vanderhoof
# Processing Record 45 of Set 21 | awash
# Processing Record 46 of Set 21 | barzas
# Processing Record 47 of Set 21 | kalmunai
# Processing Record 48 of Set 21 | narok
# Processing Record 49 of Set 21 | thunder bay
# Processing Record 50 of Set 21 | nalut
# Processing Record 1 of Set 22 | talnakh
# Processing Record 2 of Set 22 | riyadh
# Processing Record 3 of Set 22 | half moon bay
# Processing Record 4 of Set 22 | wageningen
# Processing Record 5 of Set 22 | yaan
# Processing Record 6 of Set 22 | longlac
# City not found. Skipping...
# Processing Record 7 of Set 22 | champerico
# Processing Record 8 of Set 22 | barentsburg
# City not found. Skipping...
# Processing Record 9 of Set 22 | naze
# Processing Record 10 of Set 22 | nyurba
# Processing Record 11 of Set 22 | gweru
# Processing Record 12 of Set 22 | challans
# Processing Record 13 of Set 22 | hammerfest
# Processing Record 14 of Set 22 | lagoa
# Processing Record 15 of Set 22 | paradwip
# City not found. Skipping...
# Processing Record 16 of Set 22 | maniitsoq
# Processing Record 17 of Set 22 | hurghada
# Processing Record 18 of Set 22 | hofn
# Processing Record 19 of Set 22 | shimoda
# Processing Record 20 of Set 22 | yanan
# City not found. Skipping...
# Processing Record 21 of Set 22 | tual
# Processing Record 22 of Set 22 | nizhneyansk
# City not found. Skipping...
# Processing Record 23 of Set 22 | tabat
# Processing Record 24 of Set 22 | bumba
# Processing Record 25 of Set 22 | ostrovnoy
# Processing Record 26 of Set 22 | ukiah
# Processing Record 27 of Set 22 | kang
# Processing Record 28 of Set 22 | tungor
# Processing Record 29 of Set 22 | mwingi
# Processing Record 30 of Set 22 | valdivia
# Processing Record 31 of Set 22 | atambua
# Processing Record 32 of Set 22 | kota kinabalu
# Processing Record 33 of Set 22 | jati
# Processing Record 34 of Set 22 | kitimat
# Processing Record 35 of Set 22 | kondinskoye
# Processing Record 36 of Set 22 | dom pedrito
# Processing Record 37 of Set 22 | priiskovyy
# Processing Record 38 of Set 22 | turkistan
# Processing Record 39 of Set 22 | port lincoln
# Processing Record 40 of Set 22 | windsor
# Processing Record 41 of Set 22 | nouadhibou
# Processing Record 42 of Set 22 | wetaskiwin
# Processing Record 43 of Set 22 | pueblo nuevo
# Processing Record 44 of Set 22 | cururupu
# Processing Record 45 of Set 22 | ahipara
# Processing Record 46 of Set 22 | dormidontovka
# Processing Record 47 of Set 22 | alvaraes
# Processing Record 48 of Set 22 | rawson
# Processing Record 49 of Set 22 | gualeguay
# Processing Record 50 of Set 22 | oakdale
# Processing Record 1 of Set 23 | auki
# Processing Record 2 of Set 23 | teya
# Processing Record 3 of Set 23 | boa vista
# Processing Record 4 of Set 23 | nassau
# Processing Record 5 of Set 23 | araouane
# Processing Record 6 of Set 23 | umzimvubu
# City not found. Skipping...
# Processing Record 7 of Set 23 | visp
# Processing Record 8 of Set 23 | ulladulla
# Processing Record 9 of Set 23 | stamsund
# City not found. Skipping...
# Processing Record 10 of Set 23 | lolua
# City not found. Skipping...
# Processing Record 11 of Set 23 | scarborough
# Processing Record 12 of Set 23 | energeticheskiy
# Processing Record 13 of Set 23 | santiago de cao
# Processing Record 14 of Set 23 | serowe
# Processing Record 15 of Set 23 | aasiaat
# Processing Record 16 of Set 23 | aswan
# Processing Record 17 of Set 23 | shingu
# Processing Record 18 of Set 23 | batagay-alyta
# Processing Record 19 of Set 23 | borogontsy
# Processing Record 20 of Set 23 | esmeraldas
# Processing Record 21 of Set 23 | srednekolymsk
# Processing Record 22 of Set 23 | harper
# Processing Record 23 of Set 23 | a coruna
# Processing Record 24 of Set 23 | puerto escondido
# Processing Record 25 of Set 23 | codrington
# Processing Record 26 of Set 23 | kuching
# Processing Record 27 of Set 23 | vyshneve
# Processing Record 28 of Set 23 | rungata
# City not found. Skipping...
# Processing Record 29 of Set 23 | beboto
# Processing Record 30 of Set 23 | ulaangom
# Processing Record 31 of Set 23 | vestmannaeyjar
# Processing Record 32 of Set 23 | san jose de rio tinto
# Processing Record 33 of Set 23 | padang
# Processing Record 34 of Set 23 | mogadishu
# Processing Record 35 of Set 23 | sehithwa
# Processing Record 36 of Set 23 | san buenaventura
# Processing Record 37 of Set 23 | souillac
# Processing Record 38 of Set 23 | puerto del rosario
# Processing Record 39 of Set 23 | sao joao do piaui
# Processing Record 40 of Set 23 | barcelos
# Processing Record 41 of Set 23 | hambantota
# Processing Record 42 of Set 23 | svoronos
# Processing Record 43 of Set 23 | columbus
# Processing Record 44 of Set 23 | salvador
# Processing Record 45 of Set 23 | buraydah
# Processing Record 46 of Set 23 | yulara
# Processing Record 47 of Set 23 | toyooka
# Processing Record 48 of Set 23 | burnie
# Processing Record 49 of Set 23 | menongue
# Processing Record 50 of Set 23 | arlit
# Processing Record 1 of Set 24 | linshu
# City not found. Skipping...
# Processing Record 2 of Set 24 | ust-tsilma
# Processing Record 3 of Set 24 | garowe
# Processing Record 4 of Set 24 | lishui
# Processing Record 5 of Set 24 | aripuana
# Processing Record 6 of Set 24 | borba
# Processing Record 7 of Set 24 | bilibino
# Processing Record 8 of Set 24 | atar
# Processing Record 9 of Set 24 | bereda
# Processing Record 10 of Set 24 | skalistyy
# City not found. Skipping...
# Processing Record 11 of Set 24 | tevaitoa
# Processing Record 12 of Set 24 | sirjan
# Processing Record 13 of Set 24 | oktyabrskiy
# Processing Record 14 of Set 24 | red deer
# Processing Record 15 of Set 24 | lompoc
# Processing Record 16 of Set 24 | kushima
# Processing Record 17 of Set 24 | beringovskiy
# Processing Record 18 of Set 24 | mugumu
# Processing Record 19 of Set 24 | vylkove
# Processing Record 20 of Set 24 | mosquera
# Processing Record 21 of Set 24 | sao jose da coroa grande
# Processing Record 22 of Set 24 | hirado
# Processing Record 23 of Set 24 | avallon
# Processing Record 24 of Set 24 | aksarka
# Processing Record 25 of Set 24 | torbay
# Processing Record 26 of Set 24 | kolyvan
# Processing Record 27 of Set 24 | manta
# Processing Record 28 of Set 24 | tahoua
# Processing Record 29 of Set 24 | bacong
# Processing Record 30 of Set 24 | kahramanmaras
# Processing Record 31 of Set 24 | darnah
# Processing Record 32 of Set 24 | oktyabrskoye
# Processing Record 33 of Set 24 | tambopata
# Processing Record 34 of Set 24 | zhitikara
# City not found. Skipping...
# Processing Record 35 of Set 24 | rio grande
# Processing Record 36 of Set 24 | fatikchhari
# City not found. Skipping...
# Processing Record 37 of Set 24 | saryozek
# Processing Record 38 of Set 24 | college
# Processing Record 39 of Set 24 | abu kamal
# Processing Record 40 of Set 24 | kerewan
# Processing Record 41 of Set 24 | atherton
# Processing Record 42 of Set 24 | ballina
# Processing Record 43 of Set 24 | buala
# Processing Record 44 of Set 24 | dalvik
# Processing Record 45 of Set 24 | sitka
# Processing Record 46 of Set 24 | hirson
# Processing Record 47 of Set 24 | correntina
# Processing Record 48 of Set 24 | hamilton
# Processing Record 49 of Set 24 | voh
# Processing Record 50 of Set 24 | carmignano
# Processing Record 1 of Set 25 | san antonio
# Processing Record 2 of Set 25 | raub
# Processing Record 3 of Set 25 | krasnoselkup
# Processing Record 4 of Set 25 | cockburn town
# Processing Record 5 of Set 25 | santa isabel do rio negro
# Processing Record 6 of Set 25 | mitzic
# Processing Record 7 of Set 25 | san carlos de bariloche
# Processing Record 8 of Set 25 | gravdal
# Processing Record 9 of Set 25 | ngukurr
# City not found. Skipping...
# Processing Record 10 of Set 25 | chisec
# Processing Record 11 of Set 25 | jacareacanga
# Processing Record 12 of Set 25 | puerto madryn
# Processing Record 13 of Set 25 | rivera
# Processing Record 14 of Set 25 | mpanda
# Processing Record 15 of Set 25 | siuna
# Processing Record 16 of Set 25 | yanchukan
# City not found. Skipping...
# Processing Record 17 of Set 25 | silae
# Processing Record 18 of Set 25 | ambilobe
# Processing Record 19 of Set 25 | tautira
# Processing Record 20 of Set 25 | calama
# Processing Record 21 of Set 25 | socorro
# Processing Record 22 of Set 25 | hay river
# Processing Record 23 of Set 25 | kuytun
# Processing Record 24 of Set 25 | loknya
# Processing Record 25 of Set 25 | bulaevo
# Processing Record 26 of Set 25 | tacoronte
# Processing Record 27 of Set 25 | atasu
# Processing Record 28 of Set 25 | ayan
# Processing Record 29 of Set 25 | jalu
# Processing Record 30 of Set 25 | salalah
# Processing Record 31 of Set 25 | colquechaca
# Processing Record 32 of Set 25 | beira
# Processing Record 33 of Set 25 | vichayal
# City not found. Skipping...
# Processing Record 34 of Set 25 | terrasini
# Processing Record 35 of Set 25 | gold coast
# Processing Record 36 of Set 25 | rabo de peixe
# Processing Record 37 of Set 25 | mbandaka
# Processing Record 38 of Set 25 | niquero
# Processing Record 39 of Set 25 | rundu
# Processing Record 40 of Set 25 | bilma
# Processing Record 41 of Set 25 | capreol
# Processing Record 42 of Set 25 | varkaus
# Processing Record 43 of Set 25 | sirkali
# City not found. Skipping...
# Processing Record 44 of Set 25 | woodland
# Processing Record 45 of Set 25 | matara
# Processing Record 46 of Set 25 | fuerte olimpo
# Processing Record 47 of Set 25 | mbanza-ngungu
# Processing Record 48 of Set 25 | umba
# Processing Record 49 of Set 25 | tacuarembo
# Processing Record 50 of Set 25 | pital
# Processing Record 1 of Set 26 | hualmay
# Processing Record 2 of Set 26 | olafsvik
# Processing Record 3 of Set 26 | kudahuvadhoo
# Processing Record 4 of Set 26 | pisco
# Processing Record 5 of Set 26 | vangazi
# Processing Record 6 of Set 26 | karpogory
# Processing Record 7 of Set 26 | madimba
# Processing Record 8 of Set 26 | toktogul
# Processing Record 9 of Set 26 | hastings
# Processing Record 10 of Set 26 | aykhal
# Processing Record 11 of Set 26 | kokopo
# Processing Record 12 of Set 26 | nahavand
# Processing Record 13 of Set 26 | carberry
# Processing Record 14 of Set 26 | wau
# Processing Record 15 of Set 26 | hirna
# Processing Record 16 of Set 26 | kamenka
# Processing Record 17 of Set 26 | halifax
# Processing Record 18 of Set 26 | naryan-mar
# Processing Record 19 of Set 26 | tongchuan
# Processing Record 20 of Set 26 | ovre ardal
# Processing Record 21 of Set 26 | semnan
# Processing Record 22 of Set 26 | tres arroyos
# Processing Record 23 of Set 26 | benque viejo
# City not found. Skipping...
# Processing Record 24 of Set 26 | bose
# Processing Record 25 of Set 26 | sisimiut
# Processing Record 26 of Set 26 | iquique
# Processing Record 27 of Set 26 | jining
# Processing Record 28 of Set 26 | kawana waters
# City not found. Skipping...
# Processing Record 29 of Set 26 | kyaka
# Processing Record 30 of Set 26 | shu
# Processing Record 31 of Set 26 | ngawen
# Processing Record 32 of Set 26 | hanstholm
# Processing Record 33 of Set 26 | berkak
# Processing Record 34 of Set 26 | najran
# Processing Record 35 of Set 26 | bima
# Processing Record 36 of Set 26 | ponta delgada
# Processing Record 37 of Set 26 | viligili
# City not found. Skipping...
# Processing Record 38 of Set 26 | benghazi
# Processing Record 39 of Set 26 | mapimi
# Processing Record 40 of Set 26 | mgandu
# Processing Record 41 of Set 26 | leningradskiy
# Processing Record 42 of Set 26 | nabire
# Processing Record 43 of Set 26 | bathsheba
# Processing Record 44 of Set 26 | tutoia
# Processing Record 45 of Set 26 | astoria
# Processing Record 46 of Set 26 | mareeba
# Processing Record 47 of Set 26 | mehamn
# Processing Record 48 of Set 26 | itarema
# Processing Record 49 of Set 26 | virginia beach
# Processing Record 50 of Set 26 | srivardhan
# Processing Record 1 of Set 27 | sibu
# Processing Record 2 of Set 27 | jatai
# Processing Record 3 of Set 27 | bajo baudo
# City not found. Skipping...
# Processing Record 4 of Set 27 | ondjiva
# Processing Record 5 of Set 27 | dzilam gonzalez
# Processing Record 6 of Set 27 | magdagachi
# Processing Record 7 of Set 27 | coolum beach
# Processing Record 8 of Set 27 | obzor
# Processing Record 9 of Set 27 | charters towers
# Processing Record 10 of Set 27 | dolbeau
# City not found. Skipping...
# Processing Record 11 of Set 27 | great yarmouth
# Processing Record 12 of Set 27 | coracao de jesus
# Processing Record 13 of Set 27 | saint john
# Processing Record 14 of Set 27 | presidencia roque saenz pena
# Processing Record 15 of Set 27 | armizonskoye
# Processing Record 16 of Set 27 | freising
# Processing Record 17 of Set 27 | caravelas
# Processing Record 18 of Set 27 | byron bay
# Processing Record 19 of Set 27 | shitkino
# Processing Record 20 of Set 27 | veraval
# Processing Record 21 of Set 27 | perivolion
# Processing Record 22 of Set 27 | zachary
# Processing Record 23 of Set 27 | belaya gora
# Processing Record 24 of Set 27 | weligama
# Processing Record 25 of Set 27 | stokmarknes
# Processing Record 26 of Set 27 | halalo
# City not found. Skipping...
# Processing Record 27 of Set 27 | laguna
# Processing Record 28 of Set 27 | samatau
# City not found. Skipping...
# Processing Record 29 of Set 27 | rawannawi
# City not found. Skipping...
# Processing Record 30 of Set 27 | beyneu
# Processing Record 31 of Set 27 | krasnyy chikoy
# Processing Record 32 of Set 27 | mutsamudu
# City not found. Skipping...
# Processing Record 33 of Set 27 | jieshou
# Processing Record 34 of Set 27 | gua musang
# Processing Record 35 of Set 27 | karaton
# Processing Record 36 of Set 27 | haines junction
# Processing Record 37 of Set 27 | mitsamiouli
# Processing Record 38 of Set 27 | gobo
# Processing Record 39 of Set 27 | tselinnoye
# Processing Record 40 of Set 27 | olinda
# Processing Record 41 of Set 27 | rotterdam
# Processing Record 42 of Set 27 | lahat
# Processing Record 43 of Set 27 | dombarovskiy
# Processing Record 44 of Set 27 | mundo nuevo
# Processing Record 45 of Set 27 | knysna
# Processing Record 46 of Set 27 | pedro carbo
# Processing Record 47 of Set 27 | russell
# Processing Record 48 of Set 27 | makat
# Processing Record 49 of Set 27 | mandalgovi
# Processing Record 50 of Set 27 | margate
# Processing Record 1 of Set 28 | yagodnoye
# Processing Record 2 of Set 28 | goma
# Processing Record 3 of Set 28 | helong
# Processing Record 4 of Set 28 | maralal
# Processing Record 5 of Set 28 | gurskoye
# City not found. Skipping...
# Processing Record 6 of Set 28 | quatre cocos
# Processing Record 7 of Set 28 | baykit
# Processing Record 8 of Set 28 | nibbar
# Processing Record 9 of Set 28 | yar-sale
# Processing Record 10 of Set 28 | pacifica
# Processing Record 11 of Set 28 | pombia
# Processing Record 12 of Set 28 | havelock
# Processing Record 13 of Set 28 | nelson bay
# Processing Record 14 of Set 28 | kamennomostskiy
# Processing Record 15 of Set 28 | filadelfia
# Processing Record 16 of Set 28 | mentok
# City not found. Skipping...
# Processing Record 17 of Set 28 | miraflores
# Processing Record 18 of Set 28 | rio gallegos
# Processing Record 19 of Set 28 | tsumeb
# Processing Record 20 of Set 28 | mildura
# Processing Record 21 of Set 28 | batangafo
# Processing Record 22 of Set 28 | port-gentil
# Processing Record 23 of Set 28 | noumea
# Processing Record 24 of Set 28 | cape canaveral
# Processing Record 25 of Set 28 | waddan
# Processing Record 26 of Set 28 | northam
# Processing Record 27 of Set 28 | broken hill
# Processing Record 28 of Set 28 | old saybrook
# Processing Record 29 of Set 28 | jaisalmer
# Processing Record 30 of Set 28 | paranaiba
# Processing Record 31 of Set 28 | artyk
# City not found. Skipping...
# Processing Record 32 of Set 28 | imbituba
# Processing Record 33 of Set 28 | lucea
# Processing Record 34 of Set 28 | kibungo
# Processing Record 35 of Set 28 | elizabeth city
# Processing Record 36 of Set 28 | bakel
# Processing Record 37 of Set 28 | kefamenanu
# Processing Record 38 of Set 28 | gazojak
# Processing Record 39 of Set 28 | albury
# Processing Record 40 of Set 28 | meyungs
# City not found. Skipping...
# Processing Record 41 of Set 28 | phan thiet
# Processing Record 42 of Set 28 | la ronge
# Processing Record 43 of Set 28 | owando
# Processing Record 44 of Set 28 | brooks
# Processing Record 45 of Set 28 | gat
# Processing Record 46 of Set 28 | necochea
# Processing Record 47 of Set 28 | xichang
# Processing Record 48 of Set 28 | mulchen
# Processing Record 49 of Set 28 | soyo
# Processing Record 50 of Set 28 | munger
# Processing Record 1 of Set 29 | emba
# Processing Record 2 of Set 29 | shangzhi
# Processing Record 3 of Set 29 | kasama
# Processing Record 4 of Set 29 | yarensk
# Processing Record 5 of Set 29 | chirongui
# Processing Record 6 of Set 29 | moron
# Processing Record 7 of Set 29 | oskarshamn
# Processing Record 8 of Set 29 | leeton
# Processing Record 9 of Set 29 | belmonte
# Processing Record 10 of Set 29 | zhigansk
# Processing Record 11 of Set 29 | banamba
# Processing Record 12 of Set 29 | dosso
# Processing Record 13 of Set 29 | lephepe
# City not found. Skipping...
# Processing Record 14 of Set 29 | ninghai
# Processing Record 15 of Set 29 | cabra
# Processing Record 16 of Set 29 | segovia
# Processing Record 17 of Set 29 | samarai
# Processing Record 18 of Set 29 | moranbah
# Processing Record 19 of Set 29 | pierre
# Processing Record 20 of Set 29 | anadyr
# Processing Record 21 of Set 29 | langangen
# City not found. Skipping...
# Processing Record 22 of Set 29 | hihifo
# City not found. Skipping...
# Processing Record 23 of Set 29 | akom
# Processing Record 24 of Set 29 | cunha
# Processing Record 25 of Set 29 | beaver falls
# Processing Record 26 of Set 29 | itirapina
# Processing Record 27 of Set 29 | sinnamary
# Processing Record 28 of Set 29 | ngunguru
# Processing Record 29 of Set 29 | portales
# Processing Record 30 of Set 29 | san cristobal
# Processing Record 31 of Set 29 | abonnema
# Processing Record 32 of Set 29 | sarakhs
# Processing Record 33 of Set 29 | flin flon
# Processing Record 34 of Set 29 | vaitupu
# City not found. Skipping...
# Processing Record 35 of Set 29 | ust-omchug
# Processing Record 36 of Set 29 | goderich
# Processing Record 37 of Set 29 | edson
# Processing Record 38 of Set 29 | parrita
# Processing Record 39 of Set 29 | oksfjord
# Processing Record 40 of Set 29 | tignere
# Processing Record 41 of Set 29 | lipin bor
# Processing Record 42 of Set 29 | khani
# Processing Record 43 of Set 29 | meulaboh
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert to DF
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Klaksvik      FO  62.2266   -6.5890     49.12        78          94
# 1      Shahreza      IR  32.0339   51.8794     55.83        27           0
# 2       Rikitea      PF -23.1203 -134.9692     79.65        76           7
# 3     Carnarvon      AU -24.8667  113.6333     77.07        88           5
# 4  Kruisfontein      ZA -34.0033   24.7314     74.73        70          12
#
#    Wind Speed Current Description
# 0       28.70     overcast clouds
# 1        5.17           clear sky
# 2        8.48          light rain
# 3        9.22           clear sky
# 4       13.62          few clouds

# %%
# Create the output file (CSV)
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export city_data_df into a csv.
city_data_df.to_csv(output_data_file, index_label = "City ID")
